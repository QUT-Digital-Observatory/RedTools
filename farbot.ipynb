# %%
from far_bot import run

# %%
run('prostate cancer', '2020-01-01', '2024-12-31', save=True)

# %%
from api import AusRedditData

# %%
caller = AusRedditData()

# %%
search_p_c = caller.get_submission_aggregates("prostate cancer", "2009-01-01", "2025-12-31", 'month')

# %%
search_p_t = caller.get_submission_aggregates("psa test", "2009-01-01", "2025-12-31", 'month')

# %%
search_mo = caller.get_submission_aggregates("movember", "2009-01-01", "2025-12-31", 'month')

# %%
search_p_s = caller.get_submission_aggregates("psa screening", "2009-01-01", "2025-12-31", 'month')

# %%
search_pet_scan = caller.get_submission_aggregates("pet scan", "2009-01-01", "2025-12-31", 'month')

# %%
search_pet_ct = caller.get_submission_aggregates("pet ct", "2009-01-01", "2025-12-31", 'month')

# %%
search_psma = caller.get_submission_aggregates("psma", "2009-01-01", "2025-12-31", 'month')

# %%
search_ralp = caller.get_submission_aggregates("ralp", "2009-01-01", "2025-12-31", 'month')

# %%
search_mo.to_csv('movember.csv', index=False)
search_p_c.to_csv('prostate_cancer.csv', index=False)
search_p_t.to_csv('psa_test.csv', index=False)
search_p_s.to_csv('psa_screening.csv', index=False)
search_pet_scan.to_csv('pet_scan.csv', index=False)
search_pet_ct.to_csv('pet_ct.csv', index=False)
search_psma.to_csv('psma.csv', index=False)
search_ralp.to_csv('ralp.csv', index=False)

# %%
search_subs_mo = caller.search_submissions("movember", start="2009-01-01", end="2025-12-31")

# %%
search_subs_p_c= caller.search_submissions("prostate cancer", start="2009-01-01", end="2025-12-31")
search_subs_p_t = caller.search_submissions("psa test", start="2009-01-01", end="2025-12-31")
search_subs_p_s = caller.search_submissions("psa screening", start="2009-01-01", end="2025-12-31")
search_subs_pet_scan = caller.search_submissions("pet scan", start="2009-01-01", end="2025-12-31")
search_subs_pet_ct = caller.search_submissions("pet ct", start="2009-01-01", end="2025-12-31")
search_subs_psma = caller.search_submissions("psma", start="2009-01-01", end="2025-12-31")
search_subs_ralp = caller.search_submissions("ralp", start="2009-01-01", end="2025-12-31")

# %%
search_subs_mo.to_csv('movember_submissions.csv', index=False)
search_subs_p_c.to_csv('prostate_cancer_submissions.csv', index=False)
search_subs_p_t.to_csv('psa_test_submissions.csv', index=False)
search_subs_p_s.to_csv('psa_screening_submissions.csv', index=False)
search_subs_pet_scan.to_csv('pet_scan_submissions.csv', index=False)
search_subs_pet_ct.to_csv('pet_ct_submissions.csv', index=False)
search_subs_psma.to_csv('psma_submissions.csv', index=False)

# %%
comms = caller.get_comments(submission_ids='jvjwt1')

# %%
carmen_vape_ban_1 = caller.get_submission_aggregates("vape ban", "2024-01-01", "2024-06-30", 'week')
carmen_vaping_ban_1 = caller.get_submission_aggregates("vaping ban", start="2024-01-01", end="2024-06-30", period= 'week')
carmen_vape_law_1 = caller.get_submission_aggregates("vape law", start="2024-01-01", end="2024-06-30", period= 'week')
carmen_vaping_laws_1 = caller.get_submission_aggregates("vaping laws", start="2024-01-01", end="2024-06-30", period= 'week')
carmen_vape_legislation_1 = caller.get_submission_aggregates("vape legislation", start="2024-01-01", end="2024-06-30", period= 'week')
carmen_vape_policy_1 = caller.get_submission_aggregates("vape policy", start="2024-01-01", end="2024-06-30", period= 'week')
carmen_vape_reforms_1 = caller.get_submission_aggregates("vape reforms", start="2024-01-01", end="2024-06-30", period= 'week')
carmen_vape_crackdown_1 = caller.get_submission_aggregates("vape crackdown", start="2024-01-01", end="2024-06-30", period= 'week')
carmen_vape_regulation_1 = caller.get_submission_aggregates("vape regulation", start="2024-01-01", end="2024-06-30", period= 'week')
carmen_vape_supplier_1  = caller.get_submission_aggregates("vape supplier", start="2024-01-01", end="2024-06-30", period= 'week')
carmen_vape_dealer_1  = caller.get_submission_aggregates("vape dealer", start="2024-01-01", end="2024-06-30", period= 'week')   
carmen_nicotine_prescription_1  = caller.get_submission_aggregates("nicotine prescription", start="2024-01-01", end="2024-06-30", period= 'week')
carmen_prescription_vapes_1  = caller.get_submission_aggregates("prescription vapes", start="2024-01-01", end="2024-06-30", period= 'week')
carmen_pharmacy_vapes_1  = caller.get_submission_aggregates("pharmacy vapes", start="2024-01-01", end="2024-06-30", period= 'week')
carmen_pharmacy_only_vapes_1  = caller.get_submission_aggregates("pharmacy only vapes", start="2024-01-01", end="2024-06-30", period= 'week')
carmen_pharmacy_model_1 = caller.get_submission_aggregates("pharmacy model", start="2024-01-01", end="2024-06-30", period= 'week')
carmen_illegal_vape_1 = caller.get_submission_aggregates("illegal vape", start="2024-01-01", end="2024-06-30", period= 'week')
carmen_black_market_vapes_1 = caller.get_submission_aggregates("black market vapes", start="2024-01-01", end="2024-06-30", period= 'week')
carmen_under_the_counter_vapes_1 = caller.get_submission_aggregates("under the counter vapes", start="2024-01-01", end="2024-06-30", period= 'week')

# %%
carmen_search_vape_ban_1 = caller.search_submissions("vape ban", start="2024-01-01", end="2024-06-30")
carmen_search_vaping_ban_1 = caller.search_submissions("vaping ban", start="2024-01-01", end="2024-06-30")
carmen_search_vape_law_1 = caller.search_submissions("vape law", start="2024-01-01", end="2024-06-30")
carmen_search_vaping_laws_1 = caller.search_submissions("vaping laws", start="2024-01-01", end="2024-06-30")
carmen_search_vape_legislation_1 = caller.search_submissions("vape legislation", start="2024-01-01", end="2024-06-30")
carmen_search_vape_policy_1 = caller.search_submissions("vape policy", start="2024-01-01", end="2024-06-30")
carmen_search_vape_reforms_1 = caller.search_submissions("vape reforms", start="2024-01-01", end="2024-06-30")
carmen_search_vape_crackdown_1 = caller.search_submissions("vape crackdown", start="2024-01-01", end="2024-06-30")
carmen_search_vape_regulation_1 = caller.search_submissions("vape regulation", start="2024-01-01", end="2024-06-30")   
carmen_search_vape_supplier_1  = caller.search_submissions("vape supplier", start="2024-01-01", end="2024-06-30")
carmen_search_vape_dealer_1  = caller.search_submissions("vape dealer", start="2024-01-01", end="2024-06-30")   
carmen_search_nicotine_prescription_1  = caller.search_submissions("nicotine prescription", start="2024-01-01", end="2024-06-30")
carmen_search_prescription_vapes_1  = caller.search_submissions("prescription vapes", start="2024-01-01", end="2024-06-30") 
carmen_search_pharmacy_vapes_1  = caller.search_submissions("pharmacy vapes", start="2024-01-01", end="2024-06-30")
carmen_search_pharmacy_only_vapes_1  = caller.search_submissions("pharmacy only vapes", start="2024-01-01", end="2024-06-30")
carmen_search_pharmacy_model_1 = caller.search_submissions("pharmacy model", start="2024-01-01", end="2024-06-30")
carmen_search_illegal_vape_1 = caller.search_submissions("illegal vape", start="2024-01-01", end="2024-06-30")
carmen_search_black_market_vapes_1 = caller.search_submissions("black market vapes", start="2024-01-01", end="2024-06-30")
carmen_search_under_the_counter_vapes_1 = caller.search_submissions("under the counter vapes", start="2024-01-01", end="2024-06-30")

# %%
comments_vape_ban_1_1dnow7t = caller.get_comments(submission_ids='1dnow7t')

# %%
carmen_vape_ban_1.to_csv('vape_ban.csv', index=False)
carmen_vaping_ban_1.to_csv('vaping_ban.csv', index=False)
carmen_vape_law_1.to_csv('vape_law.csv', index=False)
carmen_vaping_laws_1.to_csv('vaping_laws.csv', index=False)
carmen_vape_legislation_1.to_csv('vape_legislation.csv', index=False)
carmen_vape_policy_1.to_csv('vape_policy.csv', index=False)
carmen_vape_reforms_1.to_csv('vape_reforms.csv', index=False)
carmen_vape_crackdown_1.to_csv('vape_crackdown.csv', index=False)
carmen_vape_regulation_1.to_csv('vape_regulation.csv', index=False)
carmen_vape_supplier_1.to_csv('vape_supplier.csv', index=False)
carmen_vape_dealer_1.to_csv('vape_dealer.csv', index=False)
carmen_nicotine_prescription_1.to_csv('nicotine_prescription.csv', index=False)
carmen_prescription_vapes_1.to_csv('prescription_vapes.csv', index=False)
carmen_pharmacy_vapes_1.to_csv('pharmacy_vapes.csv', index=False)
carmen_pharmacy_only_vapes_1.to_csv('pharmacy_only_vapes.csv', index=False)
carmen_pharmacy_model_1.to_csv('pharmacy_model.csv', index=False)
carmen_illegal_vape_1.to_csv('illegal_vape.csv', index=False)
carmen_black_market_vapes_1.to_csv('black_market_vapes.csv', index=False)
carmen_under_the_counter_vapes_1.to_csv('under_the_counter_vapes.csv', index=False) 
carmen_search_vape_ban_1.to_csv('search_vape_ban.csv', index=False)
carmen_search_vaping_ban_1.to_csv('search_vaping_ban.csv', index=False)
carmen_search_vape_law_1.to_csv('search_vape_law.csv', index=False)
carmen_search_vaping_laws_1.to_csv('search_vaping_laws.csv', index=False)
carmen_search_vape_legislation_1.to_csv('search_vape_legislation.csv', index=False) 
carmen_search_vape_policy_1.to_csv('search_vape_policy.csv', index=False)
carmen_search_vape_reforms_1.to_csv('search_vape_reforms.csv', index=False)
carmen_search_vape_crackdown_1.to_csv('search_vape_crackdown.csv', index=False)
carmen_search_vape_regulation_1.to_csv('search_vape_regulation.csv', index=False)
carmen_search_vape_supplier_1.to_csv('search_vape_supplier.csv', index=False)
carmen_search_vape_dealer_1.to_csv('search_vape_dealer.csv', index=False)
carmen_search_nicotine_prescription_1.to_csv('search_nicotine_prescription.csv', index=False)
carmen_search_prescription_vapes_1.to_csv('search_prescription_vapes.csv', index=False)
carmen_search_pharmacy_vapes_1.to_csv('search_pharmacy_vapes.csv', index=False)
carmen_search_pharmacy_only_vapes_1.to_csv('search_pharmacy_only_vapes.csv', index=False)
carmen_search_pharmacy_model_1.to_csv('search_pharmacy_model.csv', index=False)
carmen_search_illegal_vape_1.to_csv('search_illegal_vape.csv', index=False)
carmen_search_black_market_vapes_1.to_csv('search_black_market_vapes.csv', index=False)
carmen_search_under_the_counter_vapes_1.to_csv('search_under_the_counter_vapes.csv', index=False)   
comments_vape_ban_1_1dnow7t.to_csv('comments_vape_ban_1_1dnow7t.csv', index=False)
